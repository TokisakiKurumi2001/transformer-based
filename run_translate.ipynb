# %% [markdown]
# ### Chạy đoạn code dưới:

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !python3 -m spacy download en && spacy download vi
# !python3 -m pip install pyvi
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
#
# ✘ No compatible model found for 'vi' (spaCy v2.2.4).
#
# ...
#      |████████████████████████████████| 8.5MB 4.7MB/s
# ...
#      |████████████████████████████████| 747kB 38.5MB/s
# ...

# %% [markdown]
# #### Lưu ý: Phần dịch lấy ngẫu nhiên 200 câu trong phần data (hiện là tập huấn luyện). Nếu muốn nhập một câu nào đó thì vào file translate.py comment hàm *randomizeTranslate* và mở comment cho các dòng bên dưới của hàm *main()* và sau đó chạy lại.

# %%
# If running with Google Colab, uncomment this
# !ln -s "/content/drive/My\ Drive" /gdrive
# %cd "/content/drive/My Drive/transformer-original"
# !python3 translate.py -load_weights weights -src_lang vi -trg_lang en
# Out:
# /content/drive/.shortcut-targets-by-id/1TKWPjpS3APn5bh5AQ1H5gnnS2vMNy2_7/transformer-original
# loading spacy tokenizers...
# loading presaved fields...
# loading pretrained weights...
# [VI] Đồng thời, đồng chí cũng mong cũng mong muốn các đảng viên sống gương mẫu, tiếp tục cống hiến cho Đảng, cho quê hương bằng những việc làm cụ thể, thiết thực
#
# /content/drive/.shortcut-targets-by-id/1TKWPjpS3APn5bh5AQ1H5gnnS2vMNy2_7/transformer-original/Beam.py:73: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   ones = (outputs==eos_tok).nonzero() # Occurrences of end symbols for all input sentences.
# [BANA] Thoi noh, đ c kung kơ wă rim đang viên yăl arih ăn đe hyoh pơm boi, ling lang pơgop ăn đang, ăn apung đơng rim tơdrong pơm trơ tro weng alưng.
#
# -----------------------------------------
# [VI] to
#
# ...
